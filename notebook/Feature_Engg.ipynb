# %%
import pandas as pd
from ta.momentum import RSIIndicator

# %%
data = pd.read_csv("../data/Raw_data.csv")

# %%
data["Date"] = pd.to_datetime(data["Date"])
data = data.set_index("Date")

# %%
#Calculating Rsi in the window of 14
data["RSI"] = data["Close"].transform(
    lambda x: RSIIndicator(close=x, window=14).rsi()
)

# %%
#Adding moving averages of 25 and 50
data["ema_14"] = data["Close"].ewm(alpha=1/25).mean()
data["ema_25"] = data["Close"].ewm(alpha=1/50).mean()

# %%
#Finding the distances between the close and ema
data["ema_14_dis"] = (data["Close"] - data["ema_14"])/data["ema_14"]
data["ema_25_dis"] = (data["Close"] - data["ema_25"])/data["ema_25"]

# %%
#finding how spread the ema is , to know the momentum
data["ema_spread"] = (data["ema_14"] - data["ema_25"]) / data["ema_25"]

# %%
#Target 0 if todays close is less than next close and 1 if the opposite
data["Target"] = (data["Close"] < data["Close"].shift(-1)).astype(int)

# %%
#Droping NULL values 
data = data.dropna()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 90792 entries, 2010-01-21 to 2025-12-30
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Close       90792 non-null  float64
#  1   High        90792 non-null  float64
#  2   Low         90792 non-null  float64
#  3   Open        90792 non-null  float64
#  4   Volume      90792 non-null  int64
#  5   Ticker      90792 non-null  object
#  6   RSI         90792 non-null  float64
#  7   ema_14      90792 non-null  float64
#  8   ema_25      90792 non-null  float64
#  9   ema_14_dis  90792 non-null  float64
#  10  ema_25_dis  90792 non-null  float64
#  11  ema_spread  90792 non-null  float64
#  12  Target      90792 non-null  int64
# dtypes: float64(10), int64(2), object(1)
# memory usage: 9.7+ MB

# %%
data.head()
# Out:
#                  Close        High         Low        Open    Volume  \
# Date
# 2010-01-21  214.233429  218.897971  213.461095  218.491473  18611321
# 2010-01-22  214.192780  217.678490  209.243699  211.581051  39869565
# 2010-01-25  211.794479  214.304587  210.707107  213.339160  13393277
# 2010-01-27  208.847321  213.410240  207.312802  210.158272  24843485
# 2010-01-28  210.798538  212.688744  208.329079  211.377792  33223459
#
#                  Ticker        RSI      ema_14      ema_25  ema_14_dis  \
# Date
# 2010-01-21  RELIANCE.NS  36.573150  221.278580  221.318045   -0.031838
# 2010-01-22  RELIANCE.NS  36.507087  220.659616  220.772947   -0.029307
# 2010-01-25  RELIANCE.NS  32.748540  219.920234  220.122810   -0.036949
# 2010-01-27  RELIANCE.NS  28.821669  219.035132  219.347005   -0.046512
# 2010-01-28  RELIANCE.NS  34.427777  218.402031  218.786201   -0.034814
#
#             ema_25_dis  ema_spread  Target
# Date
# 2010-01-21   -0.032011   -0.000178       0
# 2010-01-22   -0.029805   -0.000513       0
# 2010-01-25   -0.037835   -0.000920       0
# 2010-01-27   -0.047868   -0.001422       1
# 2010-01-28   -0.036509   -0.001756       1

# %%
data.to_csv("../data/Processed_data.csv")
